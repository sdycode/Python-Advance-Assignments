# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Advance-Assignments/blob/main/Python_Advance_Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. What is the purpose of Python's OOP?
#
# -->
# As OOP stands for Object Oriented Programming is introduced to achieve for following purposes.
# - Code reusability
# - Create structured code
# - Integration of real time entites like objects & classes
# - To achieve data hiding or encapusulation
# - To take advantage of polymorphism
# - Develop with inheritence concept
#
#
# Q2. Where does an inheritance search look for an attribute?
#
# -->
# Order of inherience search is from bottom to top and left to right.
# objects lower in a tree inherit attributes attached to objects higher in that tree.
#
#
#
# Q3. How do you distinguish between a class object and an instance object?
#
# -->
# class object is the object which is created automatically when class is created.
# class object is required when we have to access class variables also called as static member variables.
# There is always ONE class object present for one class.
#
# instance object is unique copy or new instance of class which has separate memory allocated. So there can be numerous  copies of class called instance objects
#
# Q4. What makes the first argument in a class’s method function special?
#
# -->
# First argument in class method is always refered to the instance object.
#
# It is used to refer the instance variable of object.
#
# It is passed implicitly mainly refered with self.
#
#
# Q5. What is the purpose of the __init__ method?
#
# -->
# __init__ method is default method inside any class & called always when
# instance of class is created.
# The purpose of __init__ method is to initialise instance variables of new object created.
#
#
#
#
# Q6. What is the process for creating a class instance?
#
# --> To create class instance, assign ClassName with () to the reference variable.
# eg. t = Test()
# here, t is the class instance of Test class
#
#
#
#
# Q7. What is the process for creating a class?
#
# -->
# write class name with 'class' keyword preceed to name, then give :
# under which add class body.
#
# eg. class Test :
#
#       x = 10
#       def fun():
#         y = 0
#
#
#
#
# Q8. How would you define the superclasses of a class?
#
# -->
# Superclass of class is also called as parent class in which subclass can access functions & methods present in superclass.
# Superclass can be acheived through inheritence.
# Following example will demonstrate superclass
#
# class Test1:
#
#     def a(self) :
#         print('Inside super class Test 1..')
#
#
# class Test2(Test1):
#
#     def b(self) :
#         print('Subclass Test 2 ..')
#
# Above example is showing multilevel inheritence
