# %% [markdown]
# <a href="https://colab.research.google.com/github/sdycode/Python-Advance-Assignments/blob/main/Python_Advance_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. What is the relationship between classes and modules?
# -->
# A class is used to define a blueprint for a given object, whereas a module is used to reuse a given piece of code inside another program.
# A class can have its own instance, but a module cannot be instantiated. We use the ‘class’ keyword to define a class, whereas to use modules, we use the ‘import’ keyword.
# Modules are files present inside a package, whereas a class is used to encapsulate data and functions together inside the same unit.
#
#
# Q2. How do you make instances and classes?
# -->
# class can be created using class keyword and writing body under it like
# class variables & function definations
# An instance can be created using class name by writing class name with ()
# which will call __init__ method automatically.
# An instance created will be assigned to reference variable can be used further.
# eg.  class C:
#       pass
#
# i = C()
#
# Q3. Where and how should be class attributes created?
# -->
# class attributes should be created inside class body and before calling __init__ method.
# class Employee:
#   name = 'shubham'
#   age = 25
#
#
#
# Q4. Where and how are instance attributes created?
# -->
# instance attributes created inside __init__ method.
#
# class Employee:
#
#    def __init__(self, name, salary):
#       self.name = name
#       self.salary = salary
#
#
# Q5. What does the term "self" in a Python class mean?
# -->
#
# The term self is the implicit argument passed while create any instance of class
# @ first position.
# Other arguments are passed after it.
# The self argument is used to hold the reference of object in class defination
# in which the arguments passed to be assigned to instance variables is done using self keyword.
# i.e self is just refer to the unique instance of class.
# eg.
# class Employee:
#
#    def __init__(self, name, salary):
#       self.name = name
#       self.salary = salary
#
# E1 = Employee('shubham',5)
# E2 = Employee('mayur,6)
#   Here, E1 & E2 are 2 different instance holding different data, but in same class. So to self referes to the particular iinstance E1 & E2.
#
#
# Q6. How does a Python class handle operator overloading?
# -->
#
# The operator overloading in Python means provide extended meaning beyond their predefined operational meaning. Such as, we use the "+" operator for adding two integers as well as joining two strings or merging two lists. We can achieve this as the "+" operator is overloaded by the "int" class and "str" class.
# eg.
# class example:
#     def __init__(self, X):
#         self.X = X
#
#     # adding two objects
#     def __add__(self, U):
#         return self.X + U.X
# object_1 = example(5)
# object_2 = example( 8))
# print (": ", object_1 + object_2)  --> : 13
# object_3 = example('shubham - ')
# object_4 = example('mayur)
# print (": ", object_3 + object_4)  --> : shubham - mayur
#
#
#
# Q7. When do you consider allowing operator overloading of your classes?
# -->
#
# Operator overloading of classes is allowed only when class variables are of same data type so that they can perform any particular overloaded operation.
#
#
# Q8. What is the most popular form of operator overloading?
#
# -->
# A very popular and convenient form of operator overloading is the Addition (+) operator.
#  It performs “Addition” on numbers whereas it performs “Concatenation” on strings.
#
# Q9. What are the two most important concepts to grasp in order to comprehend Python OOP code?
# -->
# Inheritance and Polymorphism are 2 most key concepts of OOP as they also cover the basic block of OOP i.e classes & objects.
